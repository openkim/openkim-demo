# %% [markdown]
# ## Welcome to the OpenKIM tutorial at MACH 2023
#
# Examples will appear here before the tutorial

# %%
from get_data_for_hull import get_formation_energies
from scipy.spatial import ConvexHull
import matplotlib.pyplot as plt

model="EAM_Dynamo_ZopeMishin_2003_TiAl__MO_117656786760_005"

rd_hull_pts,rd_prototype_labels,rd_reference_indices=get_formation_energies(["Al","Ti"],model)

rd_hull = ConvexHull(rd_hull_pts)

plt.plot(rd_hull_pts[rd_hull.vertices,0],rd_hull_pts[rd_hull.vertices,1])
# Out:
# [-3.2987663104806284, -4.850011363251176]
